# %% [markdown]
# # Vegetable Price Prediction Using Machine Learning
# Implemented for West Bengal, Kolkata district, Bara Bazar market (Commodity = Onion)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import time
# %matplotlib inline

# %% [markdown]
# # Reading Dataset
# Vegetable Data is taken from https://agmarknet.gov.in

# %%
vegetables = pd.read_csv('Ahmedabad_Cotton.csv')
vegetables.head()
# Out:
#    Sl no. District Name Market Name Commodity                  Variety Grade  \
# 0       1     Ahmedabad   Dhandhuka    Cotton  Shanker 6 (B) 30mm FIne   FAQ
# 1       2     Ahmedabad   Dhandhuka    Cotton  Shanker 6 (B) 30mm FIne   FAQ
# 2       3     Ahmedabad   Dhandhuka    Cotton  Shanker 6 (B) 30mm FIne   FAQ
# 3       4     Ahmedabad   Dhandhuka    Cotton  Shanker 6 (B) 30mm FIne   FAQ
# 4       5     Ahmedabad   Dhandhuka    Cotton  Shanker 6 (B) 30mm FIne   FAQ
#
#    Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0                     5000                     5625
# 1                     4900                     5625
# 2                     4550                     5555
# 3                     4500                     5555
# 4                     4000                     5500
#
#    Modal Price (Rs./Quintal) Price Date
# 0                       5310  31-Dec-19
# 1                       5260  30-Dec-19
# 2                       5025  28-Dec-19
# 3                       5030  27-Dec-19
# 4                       4750  26-Dec-19

# %% [markdown]
# # Drop Unnecessary Colums
# Sl no, Commodity, Grade are not  useful so drop it

# %%
vegetables = vegetables.drop(['Sl no.','Commodity','Grade'], axis = 1)

# %% [markdown]
# # Data Selection
#
# select District Name == Kolkata <br>
# Select Market Name == Bara Bazar (Posta Bazar) <br>
# Then Select Variety == Jyoti

# %%
vegetables = vegetables[vegetables['District Name'] == "Ahmedabad"]
vegetables = vegetables[vegetables['Market Name'] == "Dhandhuka"]
vegetables.head()
# Out:
#   District Name Market Name                  Variety  Min Price (Rs./Quintal)  \
# 0     Ahmedabad   Dhandhuka  Shanker 6 (B) 30mm FIne                     5000
# 1     Ahmedabad   Dhandhuka  Shanker 6 (B) 30mm FIne                     4900
# 2     Ahmedabad   Dhandhuka  Shanker 6 (B) 30mm FIne                     4550
# 3     Ahmedabad   Dhandhuka  Shanker 6 (B) 30mm FIne                     4500
# 4     Ahmedabad   Dhandhuka  Shanker 6 (B) 30mm FIne                     4000
#
#    Max Price (Rs./Quintal)  Modal Price (Rs./Quintal) Price Date
# 0                     5625                       5310  31-Dec-19
# 1                     5625                       5260  30-Dec-19
# 2                     5555                       5025  28-Dec-19
# 3                     5555                       5030  27-Dec-19
# 4                     5500                       4750  26-Dec-19

# %%
vegetables['Price Date'] = pd.to_datetime(vegetables['Price Date'])
vegetables['Price Date'] = vegetables['Price Date'].dt.day
vegetables = vegetables.iloc[::-1]
vegetables.tail(10)
# Out:
#   District Name Market Name                  Variety  Min Price (Rs./Quintal)  \
# 9     Ahmedabad   Dhandhuka  Shanker 6 (B) 30mm FIne                     5000
# 8     Ahmedabad   Dhandhuka  Shanker 6 (B) 30mm FIne                     4880
# 7     Ahmedabad   Dhandhuka  Shanker 6 (B) 30mm FIne                     4930
# 6     Ahmedabad   Dhandhuka  Shanker 6 (B) 30mm FIne                     4790
# 5     Ahmedabad   Dhandhuka  Shanker 6 (B) 30mm FIne                     5100
# 4     Ahmedabad   Dhandhuka  Shanker 6 (B) 30mm FIne                     4000
# 3     Ahmedabad   Dhandhuka  Shanker 6 (B) 30mm FIne                     4500
# 2     Ahmedabad   Dhandhuka  Shanker 6 (B) 30mm FIne                     4550
# 1     Ahmedabad   Dhandhuka  Shanker 6 (B) 30mm FIne                     4900
# 0     Ahmedabad   Dhandhuka  Shanker 6 (B) 30mm FIne                     5000
#
#    Max Price (Rs./Quintal)  Modal Price (Rs./Quintal)  Price Date
# 9                     5505                       5250          20
# 8                     5570                       5225          21
# 7                     5620                       5275          23
# 6                     5555                       5170          24
# 5                     5505                       5300          25
# 4                     5500                       4750          26
# 3                     5555                       5030          27
# 2                     5555                       5025          28
# 1                     5625                       5260          30
# 0                     5625                       5310          31

# %% [markdown]
# # Reading Climate Data
# Weather Data is taken from https://www.wunderground.com/

# %%
climate = pd.read_csv('climate_Ahemdabad_210.csv')
vegetables.reset_index(inplace=True)
vegetables[['Temp_Max', 'Temp_Avg', 'Temp_Min', 'Dew_Max', 'Dew_Avg', 'Dew_Min', 'Humid_Max', 'Humid_Avg','Humid_Min','Wind_Max','Wind_Avg','Wind_Min','Pressure_Avg','Precipitation_Total']] = climate[['Temp_Max', 'Temp_Avg', 'Temp_Min', 'Dew_Max', 'Dew_Avg', 'Dew_Min', 'Humid_Max', 'Humid_Avg','Humid_Min','Wind_Max','Wind_Avg','Wind_Min', 'Pressure_Avg', 'Precipitation_Total']]
print(vegetables.head())
data = vegetables[['Price Date', 'Modal Price (Rs./Quintal)', 'Temp_Max', 'Temp_Avg', 'Temp_Min', 'Dew_Max', 'Dew_Avg', 'Dew_Min', 'Humid_Max', 'Humid_Avg','Humid_Min','Wind_Max','Wind_Avg','Wind_Min','Pressure_Avg', 'Precipitation_Total']] 
X = vegetables[['Price Date','Temp_Max', 'Temp_Avg', 'Temp_Min', 'Dew_Max', 'Dew_Avg', 'Dew_Min', 'Humid_Max', 'Humid_Avg','Humid_Min','Wind_Max','Wind_Avg','Wind_Min', 'Pressure_Avg', 'Precipitation_Total']]
y = vegetables[['Modal Price (Rs./Quintal)']]
print(X.shape)
# Out:
#    index District Name Market Name                  Variety  \
# 0    166     Ahmedabad   Dhandhuka  Shanker 6 (B) 30mm FIne
# 1    165     Ahmedabad   Dhandhuka  Shanker 6 (B) 30mm FIne
# 2    164     Ahmedabad   Dhandhuka  Shanker 6 (B) 30mm FIne
# 3    163     Ahmedabad   Dhandhuka  Shanker 6 (B) 30mm FIne
# 4    162     Ahmedabad   Dhandhuka  Shanker 6 (B) 30mm FIne
#
#    Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0                     5470                     5710
# 1                     5455                     5695
# 2                     5480                     5690
# 3                     5510                     5680
# 4                     5450                     5685
#
#    Modal Price (Rs./Quintal)  Price Date   Temp_Max   Temp_Avg  ...  \
# 0                       5590           1  93.823810  82.583810  ...
# 1                       5575           2  93.685714  82.421905  ...
# 2                       5585           3  93.547619  82.276190  ...
# 3                       5595           4  93.419048  82.141905  ...
# 4                       5570           5  93.304762  82.001905  ...
#
#      Dew_Avg    Dew_Min  Humid_Max  Humid_Avg  Humid_Min   Wind_Max  Wind_Avg  \
# 0  65.543810  59.347619  79.238095  59.936667  39.609524  10.900000  5.123333
# 1  65.394286  59.200000  79.314286  59.944762  39.580952  10.861905  5.088571
# 2  65.225714  59.038095  79.280952  59.895238  39.533333  10.833333  5.055714
# 3  65.078095  59.223810  79.290476  59.868571  39.628571  10.795238  5.021905
# 4  64.930476  59.066667  79.342857  59.850476  39.571429  10.757143  4.983333
#
#    Wind_Min  Pressure_Avg  Precipitation_Total
# 0  1.571429     29.534762                  0.0
# 1  1.542857     29.537143                  0.0
# 2  1.514286     29.551905                  0.0
# 3  1.504762     29.554286                  0.0
# 4  1.480952     29.560000                  0.0
#
# [5 rows x 22 columns]
# (167, 15)

# %%
sns.pairplot(data)

# %% [markdown]
# # Data is splitted into train and test set.

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
import math

# %%
X_train, X_test, y_train, y_test = train_test_split(X[:-1], y[:-1], test_size=0.3, random_state=42, shuffle = True)

# %% [markdown]
# # Implementation Of Algorithm
# Implementing Random Forest algorithm

# %%
start = time.time()
regr = RandomForestRegressor(n_estimators = 200,max_depth=300, random_state=42, criterion="mae", min_samples_split=2, oob_score = True)
regr.fit(X_train,np.reshape(np.array(y_train), (len(y_train), )))
end = time.time()
print(f"Runtime of the program is {end - start}")
# Out:
# Runtime of the program is 0.7400188446044922

# %%
predicted = regr.predict(X_test)

# %% [markdown]
# # Accuracy For Training and Testing Set

# %%
#print(y_test, predicted)
print(regr.score(X_train, y_train))
print(regr.score(X_test, y_test))
# Out:
# 0.9872962190017296
# 0.8959103750762594

# %% [markdown]
# # Feature Importance

# %%
a = np.reshape(regr.feature_importances_, (len(regr.feature_importances_),1))
a = a.tolist()
col = X.columns
for i in range(0,15):
    print(col[i],  "->" , a[i][0])
# Out:
# Price Date -> 0.03228677597510787
# Temp_Max -> 0.029144481630350935
# Temp_Avg -> 0.04442351511136216
# Temp_Min -> 0.1153636320750924
# Dew_Max -> 0.07366493140043506
# Dew_Avg -> 0.06575448242316434
# Dew_Min -> 0.05942950958903556
# Humid_Max -> 0.07740632148536934
# Humid_Avg -> 0.09867041556729894
# Humid_Min -> 0.08107763036950105
# Wind_Max -> 0.053140785086857656
# Wind_Avg -> 0.08019468289963386
# Wind_Min -> 0.062134476560428455
# Pressure_Avg -> 0.1273083598263625
# Precipitation_Total -> 0.0

# %%
'''import pickle
with open("Karad_learn_max", "rb") as f:
    rf = pickle.load(f)
rf.predict()

print(np.reshape(predicted,(len(y_test),1))- np.reshape(y_test,(len(y_test),1)))
print(predicted, y_test)
'''
# Out:
# 'import pickle\nwith open("Karad_learn_max", "rb") as f:\n    rf = pickle.load(f)\nrf.predict()\n\nprint(np.reshape(predicted,(len(y_test),1))- np.reshape(y_test,(len(y_test),1)))\nprint(predicted, y_test)\n'

# %%
b= y_test.values
b = b.reshape((len(b),))
l = len(b)
sum_a = 0
for i in range(len(predicted)):
    print(str(predicted[i]) +"->"+ str(b[i]))
    sum_a = sum_a + abs(predicted[i] - b[i])
# Out:
# 5854.325->6100
# 4651.875->4600
# 6072.375->6200
# 5489.075->5460
# 6033.3->6200
# 5440.175->5475
# 5837.025->5500
# 6106.625->6100
# 5147.175->4750
# 5824.35->5500
# 5481.775->5485
# 5423.275->5430
# 5509.15->5490
# 5768.875->5540
# 5475.25->5505
# 5448.175->5420
# 4718.375->4940
# 5452.475->5440
# 5871.1->6055
# 5502.5->5495
# 6073.575->6025
# 5493.375->5500
# 5525.85->5485
# 5511.25->5525
# 4694.25->4850
# 6015.4->6120
# 4645.575->4575
# 5617.3->5680
# 5473.7->5475
# 5114.975->4590
# 5441.3->5465
# 4710.725->4665
# 4777.35->4690
# 6097.65->6100
# 5267.725->5250
# 5568.55->5585
# 4754.9->4500
# 5929.775->5500
# 5761.825->5730
# 4629.175->4680
# 5444.75->5465
# 5436.075->5465
# 4852.025->4670
# 6103.5->6175
# 5947.275->6050
# 6109.725->6115
# 5449.925->5475
# 5817.075->5705
# 5490.65->5505
# 6116.525->6140

# %%
print(sum_a/l)
# Out:
# 100.76700000000002
